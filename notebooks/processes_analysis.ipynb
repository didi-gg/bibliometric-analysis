# %% [markdown]
# # Análisis Bibliografía: Procesos Académicos y Analítica Predictiva

# %% [markdown]
# **Objetivo:** Explorar investigaciones que analizan los procesos académicos institucionales y su relación con la analítica predictiva para mejorar la toma de decisiones.
#
# #### Palabras Claves:
# * Academic Processes
# * Institutional Data
# * Administrative Data
# * Academic Analytics
# * Educational Management
# * Enrollment Data
# * Curriculum Analytics
# * Decision Support Systems
# * Educational Planning
#
# ## Búsqueda:
# ("Academic"  OR "Academic Analytics") AND ("Predictive Modeling" OR "Data Analytics" OR "Educational Data Mining") AND ("Decision Support Systems" OR "Educational Planning")

# %%
from IPython.display import IFrame
import sys
import os

sys.path.append(os.path.abspath('../'))
import scripts.eda_bib as eda_bib

# %%
# Lista de archivos .bib para procesar
file_paths = [
    '../resultados_consolidados/processes_consolidado.bib'
]

# Crear un DataFrame de pandas con todos los datos extraídos de los archivos .bib
df = eda_bib.convert_bib_to_df(file_paths)

# %% [markdown]
# ## Análisis de keywords

# %%
eda_bib.keywords_word_cloud(df)

# %%
eda_bib.bar_chart_keywords(df)

# %% [markdown]
# ## Análisis de fuentes de publicaciones

# %%
eda_bib.journal_tree_map(df)

# %% [markdown]
# ## Análisis de autores

# %%
eda_bib.top_authors_chart(df)

# %% [markdown]
# ## Análisis de keywords con VosViewer

# %%
url = "https://app.vosviewer.com/?json=https%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1NOyTwGleZO82B3rU7aRhuEdC-7m8CUX-"

# Mostrar la página en un "iframe" dentro de Jupyter Notebook
IFrame(url, width=1200, height=600)
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="https://app.vosviewer.com/?json=https%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1NOyTwGleZO82B3rU7aRhuEdC-7m8CUX-"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
