# %% [markdown]
# # Análisis Bibliografía: Uso de Datos de Moodle y Plataformas de E-Learning

# %% [markdown]
# **Objetivo:** Investigar cómo se utilizan los datos provenientes de Moodle y otras plataformas de e-learning para desarrollar modelos predictivos y mejorar el aprendizaje.
#
# ## Palabras Clave:
# * Moodle Data
# * Learning Management Systems (LMS)
# * E-Learning Platforms
# * Virtual Learning Environments (VLE)
# * Educational Logs
# * Clickstream Data
# * Student Interaction Data
# * Online Learning Analytics
#
# ## Búsqueda
# ("Moodle Data" OR "Learning Management Systems" OR "E-Learning Platforms" OR "Virtual Learning Environments")
# AND
# ("Predictive Analytics" OR "Data Mining" OR "Machine Learning" OR "Learning Analytics")
# AND
# ("Student Performance" OR "Risk Detection" OR "Student Engagement" OR "Activity Patterns")

# %%
from IPython.display import IFrame
import sys
import os

sys.path.append(os.path.abspath('../'))
import scripts.eda_bib as eda_bib

# %%
# Lista de archivos .bib para procesar
file_paths = [
    '../resultados_consolidados/moodle_consolidado.bib'
]

# Crear un DataFrame de pandas con todos los datos extraídos de los archivos .bib
df = eda_bib.convert_bib_to_df(file_paths)

# %% [markdown]
# ## Análisis de keywords

# %%
eda_bib.keywords_word_cloud(df)

# %%
eda_bib.bar_chart_keywords(df)

# %% [markdown]
# ## Análisis de fuentes de publicaciones

# %%
eda_bib.journal_tree_map(df)

# %% [markdown]
# ## Análisis de autores

# %%
eda_bib.top_authors_chart(df)

# %% [markdown]
# ## Análisis de keywords con VosViewer

# %%
url = "https://app.vosviewer.com/?json=https%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1jcMkvsEm75GcQETZu-UHeUEkeCcJ1x2H"

# Mostrar la página en un "iframe" dentro de Jupyter Notebook
IFrame(url, width=1200, height=600)
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="https://app.vosviewer.com/?json=https%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1jcMkvsEm75GcQETZu-UHeUEkeCcJ1x2H"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
