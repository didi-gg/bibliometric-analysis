# %% [markdown]
# # Análisis Bibliografía: Deserción Escolar (Dropout Prediction)

# %% [markdown]
# **Objetivo:** Identificar estudios que abordan la predicción del abandono escolar utilizando modelos predictivos y analítica de datos.
#
# ## Palabras Clave:
# * Student Dropout
# * Academic Dropout
# * School Dropout
# * Dropout Prediction
# * Dropout Risk
# * Retention Rates
# * Dropout Factors
# * Dropout Prevention
#
# ## Búsqueda:
# ("Student Dropout" OR "Academic Dropout" OR "School Dropout" OR "Dropout Risk")
# AND
# ("Predictive Model" OR "Machine Learning" OR "Educational Data Mining" OR "Learning Analytics" OR "Early Warning Systems")
# AND
# ("Risk Factors" OR "Dropout Prevention" OR "Intervention Strategies")

# %%
from IPython.display import IFrame
import sys
import os

sys.path.append(os.path.abspath('../'))
import scripts.eda_bib as eda_bib

# %%
# Lista de archivos .bib para procesar
file_paths = [
    '../resultados_consolidados/dropout_prediction_consolidado.bib'
]

# Crear un DataFrame de pandas con todos los datos extraídos de los archivos .bib
df = eda_bib.convert_bib_to_df(file_paths)

# %% [markdown]
# ## Análisis de keywords

# %%
eda_bib.keywords_word_cloud(df)

# %%
eda_bib.bar_chart_keywords(df)

# %% [markdown]
# ## Análisis de fuentes de publicaciones

# %%
eda_bib.journal_tree_map(df)

# %% [markdown]
# ## Análisis de autores

# %%
eda_bib.top_authors_chart(df)

# %% [markdown]
# ## Análisis de keywords con VosViewer

# %%
url = "https://app.vosviewer.com/?json=https%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1fn2u8yd6lShAfa7nJUUQaWsGyNG_bkeI"

# Mostrar la página en un "iframe" dentro de Jupyter Notebook
IFrame(url, width=1200, height=600)
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="https://app.vosviewer.com/?json=https%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1fn2u8yd6lShAfa7nJUUQaWsGyNG_bkeI"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
