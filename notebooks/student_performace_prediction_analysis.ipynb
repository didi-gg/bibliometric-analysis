# %% [markdown]
# # Análisis Bibliografía: Predicción del Rendimiento Académico (Student Performance Prediction)

# %% [markdown]
# **Objetivo:** Encontrar investigaciones que se centren en la predicción del rendimiento académico de los estudiantes utilizando técnicas de analítica y modelos predictivos.
#
# ## Palabras Clave:
# * Student Performance
# * Academic Achievement
# * Performance Prediction
# * Academic Success
# * Learning Outcomes
# * Student Grades
# * Predicting Academic Performance
# * Educational Assessment
#
# ## Búsqueda:
# ("Student Performance" OR "Academic Achievement" OR "Academic Success" OR "Learning Outcomes" OR "Student Grades")
# AND
# ("Predictive Analytics" OR "Predictive Model" OR "Machine Learning" OR "Data Mining" OR "Learning Analytics")
# AND
# ("Performance Prediction" OR "Predicting Academic Performance" OR "Educational Assessment")

# %%
from IPython.display import IFrame
import sys
import os

sys.path.append(os.path.abspath('../'))
import scripts.eda_bib as eda_bib

# %%
# Lista de archivos .bib para procesar
file_paths = [
    '../resultados_consolidados/student_performance_prediction_consolidado.bib'
]

# Crear un DataFrame de pandas con todos los datos extraídos de los archivos .bib
df = eda_bib.convert_bib_to_df(file_paths)

# %% [markdown]
# ## Análisis de keywords

# %%
eda_bib.keywords_word_cloud(df)

# %%
eda_bib.bar_chart_keywords(df)

# %% [markdown]
# ## Análisis de fuentes de publicaciones

# %%
eda_bib.journal_tree_map(df)

# %% [markdown]
# ## Análisis de autores

# %%
eda_bib.top_authors_chart(df)

# %% [markdown]
# ## Análisis de keywords con VosViewer

# %%
url = "https://app.vosviewer.com/?json=https%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1Z4-8fnPnjbOJcMo3yAlVPT8lK7aAY00_"

# Mostrar la página en un "iframe" dentro de Jupyter Notebook
IFrame(url, width=1200, height=600)
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="https://app.vosviewer.com/?json=https%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1Z4-8fnPnjbOJcMo3yAlVPT8lK7aAY00_"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
